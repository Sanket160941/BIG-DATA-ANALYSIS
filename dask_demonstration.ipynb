# %%
# Install Dask library for scalable big data processing
# !pip install dask[dataframe]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dask[dataframe] in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (2026.1.2)
# Requirement already satisfied: click>=8.1 in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (from dask[dataframe]) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (from dask[dataframe]) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (from dask[dataframe]) (2024.12.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (from dask[dataframe]) (24.0)
# Requirement already satisfied: partd>=1.4.0 in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (from dask[dataframe]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (from dask[dataframe]) (6.0.2)
# Requirement already satisfied: toolz>=0.12.0 in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (from dask[dataframe]) (1.1.0)
# Requirement already satisfied: pandas>=2.0 in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (from dask[dataframe]) (2.2.1)
# Requirement already satisfied: pyarrow>=16.0 in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (from dask[dataframe]) (23.0.0)
# Requirement already satisfied: colorama in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (from click>=8.1->dask[dataframe]) (0.4.6)
# Requirement already satisfied: numpy<2,>=1.26.0 in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (from pandas>=2.0->dask[dataframe]) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (from pandas>=2.0->dask[dataframe]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (from pandas>=2.0->dask[dataframe]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (from pandas>=2.0->dask[dataframe]) (2024.1)
# Requirement already satisfied: locket in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (from partd>=1.4.0->dask[dataframe]) (1.0.0)
# Requirement already satisfied: six>=1.5 in C:\Users\Sanket M\AppData\Roaming\Python\Python312\site-packages (from python-dateutil>=2.8.2->pandas>=2.0->dask[dataframe]) (1.16.0)

# %%
## Introduction

# Big data analytics focuses on analyzing large datasets using scalable tools. 
# In this notebook, a 10 lakh record Amazon sales dataset is analyzed using Dask to demonstrate parallel. 
# Scalable data processing through efficient aggregation and analysis operations.

# %%
# Import Dask DataFrame for big data processing
import dask.dataframe as dd

# %%
# Load dataset safely by assuming missing values
df = dd.read_csv(r"Amazon_Sales_10_Lakh_Rows.csv", assume_missing=True)

# %%
# Display first few records - DATASET PREVIEW
df.head(5)
# Out:
#    index             Order ID       Date                        Status  \
# 0    1.0  405-8078784-5731545  4/30/2022                     Cancelled
# 1    2.0  171-9198151-1101146  4/30/2022  Shipped - Delivered to Buyer
# 2    3.0  404-0687676-7273146  4/30/2022                       Shipped
# 3    4.0  403-9615377-8133951  4/30/2022                     Cancelled
# 4    5.0  407-1069790-7240320  4/30/2022                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    Qty currency  Amount    ship-city   ship-state  ship-postal-code  \
# 0  0.0      INR  647.62       MUMBAI  MAHARASHTRA          400081.0
# 1  1.0      INR  406.00    BENGALURU    KARNATAKA          560085.0
# 2  1.0      INR  329.00  NAVI MUMBAI  MAHARASHTRA          410210.0
# 3  0.0      INR  753.33   PUDUCHERRY   PUDUCHERRY          605008.0
# 4  1.0      INR  574.00      CHENNAI   TAMIL NADU          600073.0
#
#   ship-country    B2B fulfilled-by
# 0           IN  False    Easy Ship
# 1           IN  False    Easy Ship
# 2           IN   True         <NA>
# 3           IN  False    Easy Ship
# 4           IN  False         <NA>

# %%
# Display last few records
df.tail(5)
# Out:
#             index             Order ID       Date               Status  \
# 499712   999996.0  407-0973793-3892365  6/24/2022  Shipped - Picked Up
# 499713   999997.0  404-5253538-0138728  6/24/2022            Cancelled
# 499714   999998.0  171-3801612-1983557  6/24/2022            Cancelled
# 499715   999999.0  408-6207072-7206730  6/24/2022            Cancelled
# 499716  1000000.0  404-7151110-6924336  6/24/2022            Cancelled
#
#        Fulfilment Sales Channel ship-service-level Category Size  \
# 499712   Merchant     Amazon.in           Standard  T-shirt   XS
# 499713     Amazon     Amazon.in          Expedited    Shirt    M
# 499714     Amazon     Amazon.in          Expedited    Shirt    L
# 499715   Merchant     Amazon.in           Standard    Shirt   XL
# 499716     Amazon     Amazon.in          Expedited  T-shirt   XL
#
#        Courier Status  Qty currency  Amount      ship-city        ship-state  \
# 499712        Shipped  1.0      INR  764.00        Kolkata       WEST BENGAL
# 499713      Cancelled  0.0     <NA>     NaN         KANGRA  HIMACHAL PRADESH
# 499714      Cancelled  0.0     <NA>     NaN      dibrugarh             ASSAM
# 499715     On the Way  0.0      INR  700.95  EAST GODAVARI    ANDHRA PRADESH
# 499716      Cancelled  0.0     <NA>     NaN      NEW DELHI             DELHI
#
#         ship-postal-code ship-country    B2B fulfilled-by
# 499712          700104.0           IN  False    Easy Ship
# 499713          176092.0           IN  False         <NA>
# 499714          786001.0           IN  False         <NA>
# 499715          533003.0           IN  False    Easy Ship
# 499716          110018.0           IN  False         <NA>

# %%
# Get total number of rows
total_rows = df.shape[0].compute()

# Get total number of columns
total_columns = len(df.columns)

total_rows, total_columns
# Out:
# (1000000, 19)

# %%
# Display all column names
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
# Check data types of each column
df.dtypes
# Out:
# index                         float64
# Order ID              string[pyarrow]
# Date                  string[pyarrow]
# Status                string[pyarrow]
# Fulfilment            string[pyarrow]
# Sales Channel         string[pyarrow]
# ship-service-level    string[pyarrow]
# Category              string[pyarrow]
# Size                  string[pyarrow]
# Courier Status        string[pyarrow]
# Qty                           float64
# currency              string[pyarrow]
# Amount                        float64
# ship-city             string[pyarrow]
# ship-state            string[pyarrow]
# ship-postal-code              float64
# ship-country          string[pyarrow]
# B2B                              bool
# fulfilled-by          string[pyarrow]
# dtype: object

# %%
# Count missing values per column
null_values = df.isnull().sum()
null_values.compute()
# Out:
# index                      0
# Order ID                   0
# Date                       0
# Status                     0
# Fulfilment                 0
# Sales Channel              0
# ship-service-level         0
# Category                   0
# Size                       0
# Courier Status             0
# Qty                        0
# currency               60430
# Amount                 60430
# ship-city                272
# ship-state               272
# ship-postal-code         272
# ship-country             272
# B2B                        0
# fulfilled-by          694254
# dtype: int64

# %%
# Replace missing values for analysis consistency
df = df.fillna({
    "Amount": 0,
    "Category": "Unknown",
    "Status": "Unknown"
})

# %%
# Again Count missing values per column for Amount analysis
null_values = df.isnull().sum()
null_values.compute()
# Out:
# index                      0
# Order ID                   0
# Date                       0
# Status                     0
# Fulfilment                 0
# Sales Channel              0
# ship-service-level         0
# Category                   0
# Size                       0
# Courier Status             0
# Qty                        0
# currency               60430
# Amount                     0
# ship-city                272
# ship-state               272
# ship-postal-code         272
# ship-country             272
# B2B                        0
# fulfilled-by          694254
# dtype: int64

# %%
# Generate summary statistics for numerical columns
df.describe().compute()
# Out:
#                 index             Qty          Amount  ship-postal-code
# count  1000000.000000  1000000.000000  1000000.000000     999728.000000
# mean    500000.500000        0.904326      609.031870     463854.474179
# std     288675.278932        0.313654      313.101963     191577.627070
# min          1.000000        0.000000        0.000000     110001.000000
# 25%     125071.500000        1.000000      411.430000     382421.000000
# 50%     375212.500000        1.000000      582.000000     500032.000000
# 75%     625213.000000        1.000000      771.000000     600024.000000
# max    1000000.000000       15.000000     5584.000000     989898.000000

# %%
# Check number of partitions (parallelism)
df.npartitions
# Out:
# 2

# %%
# Increase number of partitions to scale computation
df_scaled = df.repartition(npartitions=16)

# %%
# Verify number of partitions after scaling
df_scaled.npartitions
# Out:
# 16

# %%
# Calculate total sales amount
total_sales = df["Amount"].sum()
total_sales.compute()
# Out:
# 609031870.1800001

# %%
# Count unique values in important columns
df["Category"].nunique().compute(), df["Status"].nunique().compute()
# Out:
# (9, 13)

# %%
# Perform aggregation on scaled dataset
scaled_category_sales = df_scaled.groupby("Category")["Amount"].sum()
scaled_category_sales.compute()
# Out:
# Category
# Perfume     6.097325e+06
# T-shirt     3.044432e+08
# Trousers    4.148701e+07
# Blazzer     8.652609e+07
# Shirt       1.647410e+08
# Shoes       9.735052e+05
# Socks       1.179316e+06
# Wallet      3.577076e+06
# Watch       7.320000e+03
# Name: Amount, dtype: float64

# %%
# Calculate total sales per category
category_sales = df.groupby("Category")["Amount"].sum()
category_sales.compute().sort_values(ascending=False)
# Out:
# Category
# T-shirt     3.044432e+08
# Shirt       1.647410e+08
# Blazzer     8.652609e+07
# Trousers    4.148701e+07
# Perfume     6.097325e+06
# Wallet      3.577076e+06
# Socks       1.179316e+06
# Shoes       9.735052e+05
# Watch       7.320000e+03
# Name: Amount, dtype: float64

# %%
# Count number of orders by status
status_count = df.groupby("Status").size()
status_count.compute().sort_values(ascending=False)
# Out:
# Status
# Shipped                          602173
# Shipped - Delivered to Buyer     223866
# Cancelled                        142077
# Shipped - Returned to Seller      15280
# Shipped - Picked Up                7619
# Pending                            5247
# Pending - Waiting for Pick Up      2248
# Shipped - Returning to Seller      1048
# Shipped - Out for Delivery          254
# Shipped - Rejected by Buyer          85
# Shipping                             56
# Shipped - Lost in Transit            40
# Shipped - Damaged                     7
# dtype: int64

# %%
# Compute average sales for each category
avg_sales = df.groupby("Category")["Amount"].mean()
avg_sales.compute()
# Out:
# Category
# Blazzer     722.791446
# Perfume     682.485405
# Shirt       426.734896
# Shoes       755.827003
# Socks       342.724871
# T-shirt     779.484395
# Trousers    501.444541
# Wallet      493.594046
# Watch       305.000000
# Name: Amount, dtype: float64

# %%
# Identify top 5 categories based on total sales
top_products = df.groupby("Category")["Amount"].sum()
top_products.compute().round(0).astype(int).sort_values(ascending=False).head(5)
# Out:
# Category
# T-shirt     304443220
# Shirt       164741007
# Blazzer      86526087
# Trousers     41487014
# Perfume       6097325
# Name: Amount, dtype: int32

# %%
# Trigger full parallel execution across partitions
df_scaled.map_partitions(lambda x: x).compute()
# Out:
#             index             Order ID       Date  \
# 0             1.0  405-8078784-5731545  4/30/2022
# 1             2.0  171-9198151-1101146  4/30/2022
# 2             3.0  404-0687676-7273146  4/30/2022
# 3             4.0  403-9615377-8133951  4/30/2022
# 4             5.0  407-1069790-7240320  4/30/2022
# ...           ...                  ...        ...
# 499712   999996.0  407-0973793-3892365  6/24/2022
# 499713   999997.0  404-5253538-0138728  6/24/2022
# 499714   999998.0  171-3801612-1983557  6/24/2022
# 499715   999999.0  408-6207072-7206730  6/24/2022
# 499716  1000000.0  404-7151110-6924336  6/24/2022
#
#                               Status Fulfilment Sales Channel  \
# 0                          Cancelled   Merchant     Amazon.in
# 1       Shipped - Delivered to Buyer   Merchant     Amazon.in
# 2                            Shipped     Amazon     Amazon.in
# 3                          Cancelled   Merchant     Amazon.in
# 4                            Shipped     Amazon     Amazon.in
# ...                              ...        ...           ...
# 499712           Shipped - Picked Up   Merchant     Amazon.in
# 499713                     Cancelled     Amazon     Amazon.in
# 499714                     Cancelled     Amazon     Amazon.in
# 499715                     Cancelled   Merchant     Amazon.in
# 499716                     Cancelled     Amazon     Amazon.in
#
#        ship-service-level  Category Size Courier Status  Qty currency  Amount  \
# 0                Standard   T-shirt    S     On the Way  0.0      INR  647.62
# 1                Standard     Shirt  3XL        Shipped  1.0      INR  406.00
# 2               Expedited     Shirt   XL        Shipped  1.0      INR  329.00
# 3                Standard   Blazzer    L     On the Way  0.0      INR  753.33
# 4               Expedited  Trousers  3XL        Shipped  1.0      INR  574.00
# ...                   ...       ...  ...            ...  ...      ...     ...
# 499712           Standard   T-shirt   XS        Shipped  1.0      INR  764.00
# 499713          Expedited     Shirt    M      Cancelled  0.0     <NA>    0.00
# 499714          Expedited     Shirt    L      Cancelled  0.0     <NA>    0.00
# 499715           Standard     Shirt   XL     On the Way  0.0      INR  700.95
# 499716          Expedited   T-shirt   XL      Cancelled  0.0     <NA>    0.00
#
#             ship-city        ship-state  ship-postal-code ship-country    B2B  \
# 0              MUMBAI       MAHARASHTRA          400081.0           IN  False
# 1           BENGALURU         KARNATAKA          560085.0           IN  False
# 2         NAVI MUMBAI       MAHARASHTRA          410210.0           IN   True
# 3          PUDUCHERRY        PUDUCHERRY          605008.0           IN  False
# 4             CHENNAI        TAMIL NADU          600073.0           IN  False
# ...               ...               ...               ...          ...    ...
# 499712        Kolkata       WEST BENGAL          700104.0           IN  False
# 499713         KANGRA  HIMACHAL PRADESH          176092.0           IN  False
# 499714      dibrugarh             ASSAM          786001.0           IN  False
# 499715  EAST GODAVARI    ANDHRA PRADESH          533003.0           IN  False
# 499716      NEW DELHI             DELHI          110018.0           IN  False
#
#        fulfilled-by
# 0         Easy Ship
# 1         Easy Ship
# 2              <NA>
# 3         Easy Ship
# 4              <NA>
# ...             ...
# 499712    Easy Ship
# 499713         <NA>
# 499714         <NA>
# 499715    Easy Ship
# 499716         <NA>
#
# [1000000 rows x 19 columns]

# %%
# Scalability Check:

# - Dataset repartitioned into multiple chunks
# - Computation executed in parallel
# - Memory persistence improves performance
# - Demonstrates scalable big data processing using Dask
